# %%
scores = [0.72703,0.72491,0.71347,0.77341,0.71273,0.72790,0.70435,0.72766,0.71273,0.73202,0.70830,0.72789,0.76178,0.76471,0.71560,0.73447,0.71935,0.73486,0.71523,0.74509,0.71130,0.72612,0.71745,0.73764,0.71766,0.73750,0.72349,0.75471,0.72254,0.75559,0.72425,0.75500,0.71299,0.72712,0.72302,0.75495,0.83569,0.84007,0.83569,0.84007,0.83569,0.84007,0.83937,0.84483,0.83052,0.83516,0.79421,0.80716,0.79421,0.80716,0.84042,0.84480,0.79421,0.80716,0.79421,0.80716,0.88370,0.84039,0.84753,0.83938,0.88943,0.84721,0.89441,0.84249]
private_scores = [score for score in scores[::2]][::-1]
public_scores = [score for score in scores[1::2]][::-1]
print(private_scores)
print(public_scores)
# Out:
# [0.89441, 0.88943, 0.84753, 0.8837, 0.79421, 0.79421, 0.84042, 0.79421, 0.79421, 0.83052, 0.83937, 0.83569, 0.83569, 0.83569, 0.72302, 0.71299, 0.72425, 0.72254, 0.72349, 0.71766, 0.71745, 0.7113, 0.71523, 0.71935, 0.7156, 0.76178, 0.7083, 0.71273, 0.70435, 0.71273, 0.71347, 0.72703]
# [0.84249, 0.84721, 0.83938, 0.84039, 0.80716, 0.80716, 0.8448, 0.80716, 0.80716, 0.83516, 0.84483, 0.84007, 0.84007, 0.84007, 0.75495, 0.72712, 0.755, 0.75559, 0.75471, 0.7375, 0.73764, 0.72612, 0.74509, 0.73486, 0.73447, 0.76471, 0.72789, 0.73202, 0.72766, 0.7279, 0.77341, 0.72491]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, len(public_scores), len(public_scores))
min_score = min(private_scores)
min_score_index = private_scores.index(min_score) + 1
plt.plot(x, private_scores, label="private score")
plt.plot(x, public_scores, label="public score")
plt.plot(min_score_index, min_score, marker="x", color="red")
plt.grid()
plt.legend()
plt.show()
